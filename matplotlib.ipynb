# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
ar1=np.linspace(0,5,11)
ar2=ar1**2

# %%
ar1
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
plt.plot(ar1,ar2,'r')

# %%
plt.plot(ar1,ar2,'r')
plt.xlabel('X ------')
plt.ylabel('Y ------')
plt.title('title')
# Out:
# Text(0.5,1,'title')

# %%
plt.subplot(1,2,1)
plt.plot(ar1,ar2,'r')

# %%
plt.subplot(1,2,1)
plt.plot(ar1,ar2,'r')
plt.subplot(1,2,2)
plt.plot(ar2,ar1)

# %%
plt.subplot(9,5,3)
plt.plot(ar1,ar2)

# %%
##object oriented

fig=plt.figure()

# %%
axes=fig.add_axes([0.1,0.2,0.8,0.9])
# Out:
# C:\Users\margam\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
axes.plot(ar1,ar2)

# %%
plt.show()
plot_axes

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.2,0.8,0.9])
axes.plot(ar1,ar2)
axes.set_xlabel('X---->')
axes.set_ylabel('Y---->')
axes.set_title('Title')
# Out:
# Text(0.5,1,'Title')

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.2,0.8,0.9])
axes.plot(ar1,ar2)
axes.set_xlabel('X---->')
axes.set_ylabel('Y---->')
axes.set_title('Title')
axes1=fig.add_axes([0.5,0.7,0.3,0.3])
axes1.plot(ar1,ar2)
axes1.set_xlabel('X---->')
axes1.set_ylabel('Y---->')
axes1.set_title('Title')
# Out:
# Text(0.5,1,'Title')

# %%
fig,axes=plt.subplots(nrows=3,ncols=2)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)

for current_ax in axes:
    current_ax.plot(ar1,ar2)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(ar1,ar2)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[1].plot(ar1,ar2)

# %%
fig =plt.figure(figsize=(3,2))
ax =fig.add_axes([0,0,1,1])
ax.plot(ar1,ar2,label='ar1,ar2')
ax.plot(ar2,ar1,label='ar2,ar1')
ax.legend(loc=(0.3,0.3))

# %%
fig,axes =plt.subplots(nrows=3, ncols=5,figsize=(10,2))
axes[1].plot(ar1,ar2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-16162eaa8ead> in <module>()
#       1 fig,axes =plt.subplots(nrows=3, ncols=5,figsize=(10,2))
# ----> 2 axes[1].plot(ar1,ar2)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig.savefig('my_picture.jpg',dpi=200)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(ar1,ar2,color='#FF8C00',lw=5,linestyle='-',marker='o',mfc='yellow',ms=20)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(ar1,ar2,color='#FF8C00',lw=5,linestyle='-',marker='o',mfc='yellow',ms=20)
ax.set_xlim([0,1])
ax.set_ylim([0,2])
# Out:
# (0, 2)

# %%
plt.scatter(ar1,ar2)

# %%
plt.hist(ar1,ar2)
# Out:
# (array([ 1.,  1.,  3.,  3.,  3.,  0.,  0.,  0.,  0.,  0.]),
#  array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#          16.  ,  20.25,  25.  ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(ar1)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xefcfdd0>],
#  'caps': [<matplotlib.lines.Line2D at 0xefda610>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0xefdae10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xefdabb0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0xefcff10>,
#   <matplotlib.lines.Line2D at 0xefda370>]}
